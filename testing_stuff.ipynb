# %%
import pandas as pd

# %%
data=pd.read_csv('./cleaned.csv')

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'price', 'property_type', 'subproperty_type', 'locality',
#        'construction_year', 'total_area_sqm', 'nbr_bedrooms', 'fl_furnished',
#        'fl_open_fire', 'terrace_sqm', 'garden_sqm', 'fl_swimming_pool',
#        'fl_floodzone', 'primary_energy_consumption_sqm', 'heating_type',
#        'fl_double_glazing', 'cadastral_income', 'kitchen_type',
#        'state_of_building'],
#       dtype='object')

# %%
x=data.kitchen_type.value_counts().index.tolist()
x.sort()
print(x)
# Out:
# [1.0, 2.0, 2.6002889448132818, 2.6033070252708024, 2.60333786737291, 2.603361987478405, 2.60341343562557, 2.604927524374927, 2.6052105259598517, 2.607078241902224, 2.607080218960052, 2.6071763039704643, 2.608653513568203, 2.608975811417791, 2.6089892725739965, 2.608999338405937, 2.610983879372353, 2.612769764214228, 2.6127837382706955, 2.6150791922989645, 2.6161929812443048, 2.616530304733381, 2.616560949129706, 2.616575579357629, 2.616588430233507, 2.6166617121824407, 2.6166633607251666, 2.6166878762422265, 2.6184320260703853, 2.618438748066999, 2.6184419113595228, 2.618469787874889, 2.6185543231191364, 2.6193509572549747, 2.6194071056972734, 2.619927820011702, 2.619969140520295, 2.6200684118684934, 2.6200729360562347, 2.6203681482135868, 2.6203968155520845, 2.6204469340558325, 2.62108035929046, 2.6218754090903023, 2.622207592229027, 2.622233689392349, 2.622306049708833, 2.622339544992528, 2.6227180671798678, 2.623728494804752, 2.6241292818500885, 2.624183255528777, 2.62423215592922
# ...
